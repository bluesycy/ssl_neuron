# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import json
from ssl_neuron.datasets import build_dataloader
from ssl_neuron.graphdino import create_model
from ssl_neuron.train import Trainer

# %% [markdown]
# #### Load config

# %%
config = json.load(open('../configs/config.json'))

# %% [markdown]
# #### Load model

# %%
model = create_model(config)
model.train()
model.cuda();

# %% [markdown]
# #### Load dataset

# %%
dataloaders = build_dataloader(config)
# Out:
# 100%|██████████| 184/184 [00:01<00:00, 132.39it/s]
# 100%|██████████| 50/50 [00:00<00:00, 138.46it/s]

# %% [markdown]
# #### Run training

# %%
trainer = Trainer(config, model, dataloaders)

# %%
trainer.train()
# Out:
# Epoch 0 | Loss 4.9719
# Save model after epoch 0 as ckpt_0.pt.
# Epoch 1 | Loss 5.0023
# Epoch 2 | Loss 5.0548
# Epoch 3 | Loss 5.1500
# Epoch 4 | Loss 5.2706
# Epoch 5 | Loss 5.4701
# Epoch 6 | Loss 5.6552
# Epoch 7 | Loss 5.8581
# Epoch 8 | Loss 6.0779
# Epoch 9 | Loss 6.2586
# Epoch 10 | Loss 6.4762
# Epoch 11 | Loss 6.5983
# Epoch 12 | Loss 6.7369
# Epoch 13 | Loss 6.8257
# Epoch 14 | Loss 6.9194
# Epoch 15 | Loss 6.9531
# Epoch 16 | Loss 7.0035
# Epoch 17 | Loss 7.0480
# Epoch 18 | Loss 7.0931
# Epoch 19 | Loss 7.1388
# Epoch 20 | Loss 7.1248
# Epoch 21 | Loss 7.1339
# Epoch 22 | Loss 7.1377
# Epoch 23 | Loss 7.1599
# Epoch 24 | Loss 7.1376
# Epoch 25 | Loss 7.2012
# Epoch 26 | Loss 7.1909
# Epoch 27 | Loss 7.2390
# Epoch 28 | Loss 7.1944
# Epoch 29 | Loss 7.2039
# Epoch 30 | Loss 7.1682
# Epoch 31 | Loss 7.2091
# Epoch 32 | Loss 7.2218
# Epoch 33 | Loss 7.1890
# Epoch 34 | Loss 7.2370
# Epoch 35 | Loss 7.1837
# Epoch 36 | Loss 7.1933
# Epoch 37 | Loss 7.1851
# Epoch 38 | Loss 7.1805
# Epoch 39 | Loss 7.1905
# Epoch 40 | Loss 7.2129
# Epoch 41 | Loss 7.2302
# Epoch 42 | Loss 7.1696
# Epoch 43 | Loss 7.1643
# Epoch 44 | Loss 7.1819
# Epoch 45 | Loss 7.1479
# Epoch 46 | Loss 7.1877
# Epoch 47 | Loss 7.1771
# Epoch 48 | Loss 7.1786
# Epoch 49 | Loss 7.1655
# Epoch 50 | Loss 7.1702
# Epoch 51 | Loss 7.1543
# Epoch 52 | Loss 7.1375
# Epoch 53 | Loss 7.1722
# Epoch 54 | Loss 7.1764
# Epoch 55 | Loss 7.1408
# Epoch 56 | Loss 7.1376
# Epoch 57 | Loss 7.1538
# Epoch 58 | Loss 7.1161
# Epoch 59 | Loss 7.1885
# Epoch 60 | Loss 7.1457
# Epoch 61 | Loss 7.1419
# Epoch 62 | Loss 7.1184
# Epoch 63 | Loss 7.1347
# Epoch 64 | Loss 7.1103
# Epoch 65 | Loss 7.1048
# Epoch 66 | Loss 7.1286
# Epoch 67 | Loss 7.0877
# Epoch 68 | Loss 7.1236
# Epoch 69 | Loss 7.1049
# Epoch 70 | Loss 7.1467
# Epoch 71 | Loss 7.1075
# Epoch 72 | Loss 7.0734
# Epoch 73 | Loss 7.0631
# Epoch 74 | Loss 7.0979
# Epoch 75 | Loss 7.0664
# Epoch 76 | Loss 7.0568
# Epoch 77 | Loss 7.0622
# Epoch 78 | Loss 7.0267
# Epoch 79 | Loss 7.0581
# Epoch 80 | Loss 7.0563
# Epoch 81 | Loss 7.0500
# Epoch 82 | Loss 7.0168
# Epoch 83 | Loss 7.0504
# Epoch 84 | Loss 7.0472
# Epoch 85 | Loss 7.0138
# Epoch 86 | Loss 7.0113
# Epoch 87 | Loss 7.0083
# Epoch 88 | Loss 7.0347
# Epoch 89 | Loss 7.0452
# Epoch 90 | Loss 7.0030
# Epoch 91 | Loss 7.0006
# Epoch 92 | Loss 6.9937
# Epoch 93 | Loss 6.9594
# Epoch 94 | Loss 6.9961
# Epoch 95 | Loss 6.9697
# Epoch 96 | Loss 6.9466
# Epoch 97 | Loss 6.9758
# Epoch 98 | Loss 6.9446
# Epoch 99 | Loss 6.9198
# Epoch 100 | Loss 6.9284
# Epoch 101 | Loss 6.8973
# Epoch 102 | Loss 6.8930
# Epoch 103 | Loss 6.9233
# Epoch 104 | Loss 6.8991
# Epoch 105 | Loss 6.9103
# Epoch 106 | Loss 6.8820
# Epoch 107 | Loss 6.8545
# Epoch 108 | Loss 6.9107
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 trainer.train()
#
# File ~/ssl_neuron/ssl_neuron/train.py:45, in Trainer.train(self)
#      42 epoch = 0
#      43 while self.curr_iter < self.max_iter:
#      44     # Run one epoch.
# ---> 45     self._train_epoch(epoch)
#      47     if epoch % self.save_every == 0:
#      48         # Save checkpoint.
#      49         self._save_checkpoint(epoch)
#
# File ~/ssl_neuron/ssl_neuron/train.py:57, in Trainer._train_epoch(self, epoch)
#      55 self.model.train()
#      56 losses = AverageMeter()
# ---> 57 for i, data in enumerate(self.train_loader, 0):
#      58     f1, f2, a1, a2 = [x.float().to(self.device, non_blocking=True) for x in data]
#      59     n = a1.shape[0]
#
# File ~/miniforge3/envs/ssl/lib/python3.11/site-packages/torch/utils/data/dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File ~/miniforge3/envs/ssl/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1482, in _MultiProcessingDataLoaderIter._next_data(self)
#    1479     return self._process_data(data, worker_id)
#    1481 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1482 idx, data = self._get_data()
#    1483 self._tasks_outstanding -= 1
#    1484 if self._dataset_kind == _DatasetKind.Iterable:
#    1485     # Check for _IterableDatasetStopIteration
#
# File ~/miniforge3/envs/ssl/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1434, in _MultiProcessingDataLoaderIter._get_data(self)
#    1432 elif self._pin_memory:
#    1433     while self._pin_memory_thread.is_alive():
# -> 1434         success, data = self._try_get_data()
#    1435         if success:
#    1436             return data
#
# File ~/miniforge3/envs/ssl/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1275, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1262 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1263     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1264     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1272     # Returns a 2-tuple:
#    1273     #   (bool: whether successfully get data, any: data if successful else None)
#    1274     try:
# -> 1275         data = self._data_queue.get(timeout=timeout)
#    1276         return (True, data)
#    1277     except Exception as e:
#    1278         # At timeout and error, we manually check whether any worker has
#    1279         # failed. Note that this is the only mechanism for Windows to detect
#    1280         # worker failures.
#
# File ~/miniforge3/envs/ssl/lib/python3.11/queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File ~/miniforge3/envs/ssl/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
